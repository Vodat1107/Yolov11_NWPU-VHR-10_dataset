# %%
import os
import xml.etree.ElementTree as ET
import random
from tqdm import tqdm
import shutil
import cv2
from pathlib import Path
from PIL import Image

# %% [markdown]
# # Process positive image set

# %%
def convert_txt_to_yolo(label_file, img_dir, img_ext=".jpg"):
    label_file = Path(label_file)
    name = label_file.stem
    img_path = Path(img_dir) / f"{name}{img_ext}"

    if not img_path.exists():
        print(f"Không tìm thấy ảnh cho {label_file}")
        return

    # Lấy kích thước ảnh
    with Image.open(img_path) as im:
        w, h = im.size

    new_lines = []
    with open(label_file, "r") as f:
        for line in f:
            line = line.strip().replace("(", "").replace(")", "")
            if not line:
                continue
            x1, y1, x2, y2, cls_id = map(int, line.split(","))

            # YOLO format (normalize về [0,1])
            xc = ((x1 + x2) / 2) / w
            yc = ((y1 + y2) / 2) / h
            ww = (x2 - x1) / w
            hh = (y2 - y1) / h

            cls_id = cls_id - 1  # đổi class 1–10 -> 0–9
            new_lines.append(f"{cls_id} {xc:.6f} {yc:.6f} {ww:.6f} {hh:.6f}")

    # Ghi đè chính file txt đó
    with open(label_file, "w") as f:
        f.write("\n".join(new_lines))

    print(f"✔ Đã convert: {label_file.name}")

# %%
gt_dir = Path("/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/ground truth")
img_dir = Path("/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/positive image set")


img_ext = ".jpg"

for label_file in sorted(gt_dir.glob("*.txt")):
    convert_txt_to_yolo(label_file, img_dir, img_ext)

print("Hoàn tất convert toàn bộ nhãn sang YOLO format!")
# Out:
# ✔ Đã convert: 001.txt
# ✔ Đã convert: 002.txt
# ✔ Đã convert: 003.txt
# ✔ Đã convert: 004.txt
# ✔ Đã convert: 005.txt
# ✔ Đã convert: 006.txt
# ✔ Đã convert: 007.txt
# ✔ Đã convert: 008.txt
# ✔ Đã convert: 009.txt
# ✔ Đã convert: 010.txt
# ✔ Đã convert: 011.txt
# ✔ Đã convert: 012.txt
# ✔ Đã convert: 013.txt
# ✔ Đã convert: 014.txt
# ✔ Đã convert: 015.txt
# ✔ Đã convert: 016.txt
# ✔ Đã convert: 017.txt
# ✔ Đã convert: 018.txt
# ✔ Đã convert: 019.txt
# ✔ Đã convert: 020.txt
# ✔ Đã convert: 021.txt
# ✔ Đã convert: 022.txt
# ✔ Đã convert: 023.txt
# ✔ Đã convert: 024.txt
# ✔ Đã convert: 025.txt
# ✔ Đã convert: 026.txt
# ✔ Đã convert: 027.txt
# ✔ Đã convert: 028.txt
# ✔ Đã convert: 029.txt
# ✔ Đã convert: 030.txt
# ✔ Đã convert: 031.txt
# ✔ Đã convert: 032.txt
# ✔ Đã convert: 033.txt
# ✔ Đã convert: 034.txt
# ✔ Đã convert: 035.txt
# ✔ Đã convert: 036.txt
# ✔ Đã convert: 037.txt
# ✔ Đã convert: 038.txt
# ✔ Đã convert: 039.txt
# ✔ Đã convert: 040.txt
# ✔ Đã convert: 041.txt
# ✔ Đã convert: 042.txt
# ✔ Đã convert: 043.txt
# ✔ Đã convert: 044.txt
# ✔ Đã convert: 045.txt
# ✔ Đã convert: 046.txt
# ✔ Đã convert: 047.txt
# ✔ Đã convert: 048.txt
# ✔ Đã convert: 049.txt
# ✔ Đã convert: 050.txt
# ✔ Đã convert: 051.txt
# ✔ Đã convert: 052.txt
# ✔ Đã convert: 053.txt
# ✔ Đã convert: 054.txt
# ✔ Đã convert: 055.txt
# ✔ Đã convert: 056.txt
# ✔ Đã convert: 057.txt
# ✔ Đã convert: 058.txt
# ✔ Đã convert: 059.txt
# ✔ Đã convert: 060.txt
# ✔ Đã convert: 061.txt
# ✔ Đã convert: 062.txt
# ✔ Đã convert: 063.txt
# ✔ Đã convert: 064.txt
# ✔ Đã convert: 065.txt
# ✔ Đã convert: 066.txt
# ✔ Đã convert: 067.txt
# ✔ Đã convert: 068.txt
# ✔ Đã convert: 069.txt
# ✔ Đã convert: 070.txt
# ✔ Đã convert: 071.txt
# ✔ Đã convert: 072.txt
# ✔ Đã convert: 073.txt
# ✔ Đã convert: 074.txt
# ✔ Đã convert: 075.txt
# ✔ Đã convert: 076.txt
# ✔ Đã convert: 077.txt
# ✔ Đã convert: 078.txt
# ✔ Đã convert: 079.txt
# ✔ Đã convert: 080.txt
# ✔ Đã convert: 081.txt
# ✔ Đã convert: 082.txt
# ✔ Đã convert: 083.txt
# ✔ Đã convert: 084.txt
# ✔ Đã convert: 085.txt
# ✔ Đã convert: 086.txt
# ✔ Đã convert: 087.txt
# ✔ Đã convert: 088.txt
# ✔ Đã convert: 089.txt
# ✔ Đã convert: 090.txt
# ✔ Đã convert: 091.txt
# ✔ Đã convert: 092.txt
# ✔ Đã convert: 093.txt
# ✔ Đã convert: 094.txt
# ✔ Đã convert: 095.txt
# ✔ Đã convert: 096.txt
# ✔ Đã convert: 097.txt
# ✔ Đã convert: 098.txt
# ✔ Đã convert: 099.txt
# ✔ Đã convert: 100.txt
# ✔ Đã convert: 101.txt
# ✔ Đã convert: 102.txt
# ✔ Đã convert: 103.txt
# ✔ Đã convert: 104.txt
# ✔ Đã convert: 105.txt
# ✔ Đã convert: 106.txt
# ✔ Đã convert: 107.txt
# ✔ Đã convert: 108.txt
# ✔ Đã convert: 109.txt
# ✔ Đã convert: 110.txt
# ✔ Đã convert: 111.txt
# ✔ Đã convert: 112.txt
# ✔ Đã convert: 113.txt
# ✔ Đã convert: 114.txt
# ✔ Đã convert: 115.txt
# ✔ Đã convert: 116.txt
# ✔ Đã convert: 117.txt
# ✔ Đã convert: 118.txt
# ✔ Đã convert: 119.txt
# ✔ Đã convert: 120.txt
# ✔ Đã convert: 121.txt
# ✔ Đã convert: 122.txt
# ✔ Đã convert: 123.txt
# ✔ Đã convert: 124.txt
# ✔ Đã convert: 125.txt
# ✔ Đã convert: 126.txt
# ✔ Đã convert: 127.txt
# ✔ Đã convert: 128.txt
# ✔ Đã convert: 129.txt
# ✔ Đã convert: 130.txt
# ✔ Đã convert: 131.txt
# ✔ Đã convert: 132.txt
# ✔ Đã convert: 133.txt
# ✔ Đã convert: 134.txt
# ✔ Đã convert: 135.txt
# ✔ Đã convert: 136.txt
# ✔ Đã convert: 137.txt
# ✔ Đã convert: 138.txt
# ✔ Đã convert: 139.txt
# ✔ Đã convert: 140.txt
# ✔ Đã convert: 141.txt
# ✔ Đã convert: 142.txt
# ✔ Đã convert: 143.txt
# ✔ Đã convert: 144.txt
# ✔ Đã convert: 145.txt
# ✔ Đã convert: 146.txt
# ✔ Đã convert: 147.txt
# ✔ Đã convert: 148.txt
# ✔ Đã convert: 149.txt
# ✔ Đã convert: 150.txt
# ✔ Đã convert: 151.txt
# ✔ Đã convert: 152.txt
# ✔ Đã convert: 153.txt
# ✔ Đã convert: 154.txt
# ✔ Đã convert: 155.txt
# ✔ Đã convert: 156.txt
# ✔ Đã convert: 157.txt
# ✔ Đã convert: 158.txt
# ✔ Đã convert: 159.txt
# ✔ Đã convert: 160.txt
# ✔ Đã convert: 161.txt
# ✔ Đã convert: 162.txt
# ✔ Đã convert: 163.txt
# ✔ Đã convert: 164.txt
# ✔ Đã convert: 165.txt
# ✔ Đã convert: 166.txt
# ✔ Đã convert: 167.txt
# ✔ Đã convert: 168.txt
# ✔ Đã convert: 169.txt
# ✔ Đã convert: 170.txt
# ✔ Đã convert: 171.txt
# ✔ Đã convert: 172.txt
# ✔ Đã convert: 173.txt
# ✔ Đã convert: 174.txt
# ✔ Đã convert: 175.txt
# ✔ Đã convert: 176.txt
# ✔ Đã convert: 177.txt
# ✔ Đã convert: 178.txt
# ✔ Đã convert: 179.txt
# ✔ Đã convert: 180.txt
# ✔ Đã convert: 181.txt
# ✔ Đã convert: 182.txt
# ✔ Đã convert: 183.txt
# ✔ Đã convert: 184.txt
# ✔ Đã convert: 185.txt
# ✔ Đã convert: 186.txt
# ✔ Đã convert: 187.txt
# ✔ Đã convert: 188.txt
# ✔ Đã convert: 189.txt
# ✔ Đã convert: 190.txt
# ✔ Đã convert: 191.txt
# ✔ Đã convert: 192.txt
# ✔ Đã convert: 193.txt
# ✔ Đã convert: 194.txt
# ✔ Đã convert: 195.txt
# ✔ Đã convert: 196.txt
# ✔ Đã convert: 197.txt
# ✔ Đã convert: 198.txt
# ✔ Đã convert: 199.txt
# ✔ Đã convert: 200.txt
# ✔ Đã convert: 201.txt
# ✔ Đã convert: 202.txt
# ✔ Đã convert: 203.txt
# ✔ Đã convert: 204.txt
# ✔ Đã convert: 205.txt
# ✔ Đã convert: 206.txt
# ✔ Đã convert: 207.txt
# ✔ Đã convert: 208.txt
# ✔ Đã convert: 209.txt
# ✔ Đã convert: 210.txt
# ✔ Đã convert: 211.txt
# ✔ Đã convert: 212.txt
# ✔ Đã convert: 213.txt
# ✔ Đã convert: 214.txt
# ✔ Đã convert: 215.txt
# ✔ Đã convert: 216.txt
# ✔ Đã convert: 217.txt
# ✔ Đã convert: 218.txt
# ✔ Đã convert: 219.txt
# ✔ Đã convert: 220.txt
# ✔ Đã convert: 221.txt
# ✔ Đã convert: 222.txt
# ✔ Đã convert: 223.txt
# ✔ Đã convert: 224.txt
# ✔ Đã convert: 225.txt
# ✔ Đã convert: 226.txt
# ✔ Đã convert: 227.txt
# ✔ Đã convert: 228.txt
# ✔ Đã convert: 229.txt
# ✔ Đã convert: 230.txt
# ✔ Đã convert: 231.txt
# ✔ Đã convert: 232.txt
# ✔ Đã convert: 233.txt
# ✔ Đã convert: 234.txt
# ✔ Đã convert: 235.txt
# ✔ Đã convert: 236.txt
# ✔ Đã convert: 237.txt
# ✔ Đã convert: 238.txt
# ✔ Đã convert: 239.txt
# ✔ Đã convert: 240.txt
# ✔ Đã convert: 241.txt
# ✔ Đã convert: 242.txt
# ✔ Đã convert: 243.txt
# ✔ Đã convert: 244.txt
# ✔ Đã convert: 245.txt
# ✔ Đã convert: 246.txt
# ✔ Đã convert: 247.txt
# ✔ Đã convert: 248.txt
# ✔ Đã convert: 249.txt
# ✔ Đã convert: 250.txt
# ✔ Đã convert: 251.txt
# ✔ Đã convert: 252.txt
# ✔ Đã convert: 253.txt
# ✔ Đã convert: 254.txt
# ✔ Đã convert: 255.txt
# ✔ Đã convert: 256.txt
# ✔ Đã convert: 257.txt
# ✔ Đã convert: 258.txt
# ✔ Đã convert: 259.txt
# ✔ Đã convert: 260.txt
# ✔ Đã convert: 261.txt
# ✔ Đã convert: 262.txt
# ✔ Đã convert: 263.txt
# ✔ Đã convert: 264.txt
# ✔ Đã convert: 265.txt
# ✔ Đã convert: 266.txt
# ✔ Đã convert: 267.txt
# ✔ Đã convert: 268.txt
# ✔ Đã convert: 269.txt
# ✔ Đã convert: 270.txt
# ✔ Đã convert: 271.txt
# ✔ Đã convert: 272.txt
# ✔ Đã convert: 273.txt
# ✔ Đã convert: 274.txt
# ✔ Đã convert: 275.txt
# ✔ Đã convert: 276.txt
# ✔ Đã convert: 277.txt
# ✔ Đã convert: 278.txt
# ✔ Đã convert: 279.txt
# ✔ Đã convert: 280.txt
# ✔ Đã convert: 281.txt
# ✔ Đã convert: 282.txt
# ✔ Đã convert: 283.txt
# ✔ Đã convert: 284.txt
# ✔ Đã convert: 285.txt
# ✔ Đã convert: 286.txt
# ✔ Đã convert: 287.txt
# ✔ Đã convert: 288.txt
# ✔ Đã convert: 289.txt
# ✔ Đã convert: 290.txt
# ✔ Đã convert: 291.txt
# ✔ Đã convert: 292.txt
# ✔ Đã convert: 293.txt
# ✔ Đã convert: 294.txt
# ✔ Đã convert: 295.txt
# ✔ Đã convert: 296.txt
# ✔ Đã convert: 297.txt
# ✔ Đã convert: 298.txt
# ✔ Đã convert: 299.txt
# ✔ Đã convert: 300.txt
# ✔ Đã convert: 301.txt
# ✔ Đã convert: 302.txt
# ✔ Đã convert: 303.txt
# ✔ Đã convert: 304.txt
# ✔ Đã convert: 305.txt
# ✔ Đã convert: 306.txt
# ✔ Đã convert: 307.txt
# ✔ Đã convert: 308.txt
# ✔ Đã convert: 309.txt
# ✔ Đã convert: 310.txt
# ✔ Đã convert: 311.txt
# ✔ Đã convert: 312.txt
# ✔ Đã convert: 313.txt
# ✔ Đã convert: 314.txt
# ✔ Đã convert: 315.txt
# ✔ Đã convert: 316.txt
# ✔ Đã convert: 317.txt
# ✔ Đã convert: 318.txt
# ✔ Đã convert: 319.txt
# ✔ Đã convert: 320.txt
# ✔ Đã convert: 321.txt
# ✔ Đã convert: 322.txt
# ✔ Đã convert: 323.txt
# ✔ Đã convert: 324.txt
# ✔ Đã convert: 325.txt
# ✔ Đã convert: 326.txt
# ✔ Đã convert: 327.txt
# ✔ Đã convert: 328.txt
# ✔ Đã convert: 329.txt
# ✔ Đã convert: 330.txt
# ✔ Đã convert: 331.txt
# ✔ Đã convert: 332.txt
# ✔ Đã convert: 333.txt
# ✔ Đã convert: 334.txt
# ✔ Đã convert: 335.txt
# ✔ Đã convert: 336.txt
# ✔ Đã convert: 337.txt
# ✔ Đã convert: 338.txt
# ✔ Đã convert: 339.txt
# ✔ Đã convert: 340.txt
# ✔ Đã convert: 341.txt
# ✔ Đã convert: 342.txt
# ✔ Đã convert: 343.txt
# ✔ Đã convert: 344.txt
# ✔ Đã convert: 345.txt
# ✔ Đã convert: 346.txt
# ✔ Đã convert: 347.txt
# ✔ Đã convert: 348.txt
# ✔ Đã convert: 349.txt
# ✔ Đã convert: 350.txt
# ✔ Đã convert: 351.txt
# ✔ Đã convert: 352.txt
# ✔ Đã convert: 353.txt
# ✔ Đã convert: 354.txt
# ✔ Đã convert: 355.txt
# ✔ Đã convert: 356.txt
# ✔ Đã convert: 357.txt
# ✔ Đã convert: 358.txt
# ✔ Đã convert: 359.txt
# ✔ Đã convert: 360.txt
# ✔ Đã convert: 361.txt
# ✔ Đã convert: 362.txt
# ✔ Đã convert: 363.txt
# ✔ Đã convert: 364.txt
# ✔ Đã convert: 365.txt
# ✔ Đã convert: 366.txt
# ✔ Đã convert: 367.txt
# ✔ Đã convert: 368.txt
# ✔ Đã convert: 369.txt
# ✔ Đã convert: 370.txt
# ✔ Đã convert: 371.txt
# ✔ Đã convert: 372.txt
# ✔ Đã convert: 373.txt
# ✔ Đã convert: 374.txt
# ✔ Đã convert: 375.txt
# ✔ Đã convert: 376.txt
# ✔ Đã convert: 377.txt
# ✔ Đã convert: 378.txt
# ✔ Đã convert: 379.txt
# ✔ Đã convert: 380.txt
# ✔ Đã convert: 381.txt
# ✔ Đã convert: 382.txt
# ✔ Đã convert: 383.txt
# ✔ Đã convert: 384.txt
# ✔ Đã convert: 385.txt
# ✔ Đã convert: 386.txt
# ✔ Đã convert: 387.txt
# ✔ Đã convert: 388.txt
# ✔ Đã convert: 389.txt
# ✔ Đã convert: 390.txt
# ✔ Đã convert: 391.txt
# ✔ Đã convert: 392.txt
# ✔ Đã convert: 393.txt
# ✔ Đã convert: 394.txt
# ✔ Đã convert: 395.txt
# ✔ Đã convert: 396.txt
# ✔ Đã convert: 397.txt
# ✔ Đã convert: 398.txt
# ✔ Đã convert: 399.txt
# ✔ Đã convert: 400.txt
# ✔ Đã convert: 401.txt
# ✔ Đã convert: 402.txt
# ✔ Đã convert: 403.txt
# ✔ Đã convert: 404.txt
# ✔ Đã convert: 405.txt
# ✔ Đã convert: 406.txt
# ✔ Đã convert: 407.txt
# ✔ Đã convert: 408.txt
# ✔ Đã convert: 409.txt
# ✔ Đã convert: 410.txt
# ✔ Đã convert: 411.txt
# ✔ Đã convert: 412.txt
# ✔ Đã convert: 413.txt
# ✔ Đã convert: 414.txt
# ✔ Đã convert: 415.txt
# ✔ Đã convert: 416.txt
# ✔ Đã convert: 417.txt
# ✔ Đã convert: 418.txt
# ✔ Đã convert: 419.txt
# ✔ Đã convert: 420.txt
# ✔ Đã convert: 421.txt
# ✔ Đã convert: 422.txt
# ✔ Đã convert: 423.txt
# ✔ Đã convert: 424.txt
# ✔ Đã convert: 425.txt
# ✔ Đã convert: 426.txt
# ✔ Đã convert: 427.txt
# ✔ Đã convert: 428.txt
# ✔ Đã convert: 429.txt
# ✔ Đã convert: 430.txt
# ✔ Đã convert: 431.txt
# ✔ Đã convert: 432.txt
# ✔ Đã convert: 433.txt
# ✔ Đã convert: 434.txt
# ✔ Đã convert: 435.txt
# ✔ Đã convert: 436.txt
# ✔ Đã convert: 437.txt
# ✔ Đã convert: 438.txt
# ✔ Đã convert: 439.txt
# ✔ Đã convert: 440.txt
# ✔ Đã convert: 441.txt
# ✔ Đã convert: 442.txt
# ✔ Đã convert: 443.txt
# ✔ Đã convert: 444.txt
# ✔ Đã convert: 445.txt
# ✔ Đã convert: 446.txt
# ✔ Đã convert: 447.txt
# ✔ Đã convert: 448.txt
# ✔ Đã convert: 449.txt
# ✔ Đã convert: 450.txt
# ✔ Đã convert: 451.txt
# ✔ Đã convert: 452.txt
# ✔ Đã convert: 453.txt
# ✔ Đã convert: 454.txt
# ✔ Đã convert: 455.txt
# ✔ Đã convert: 456.txt
# ✔ Đã convert: 457.txt
# ✔ Đã convert: 458.txt
# ✔ Đã convert: 459.txt
# ✔ Đã convert: 460.txt
# ✔ Đã convert: 461.txt
# ✔ Đã convert: 462.txt
# ✔ Đã convert: 463.txt
# ✔ Đã convert: 464.txt
# ✔ Đã convert: 465.txt
# ✔ Đã convert: 466.txt
# ✔ Đã convert: 467.txt
# ✔ Đã convert: 468.txt
# ✔ Đã convert: 469.txt
# ✔ Đã convert: 470.txt
# ✔ Đã convert: 471.txt
# ✔ Đã convert: 472.txt
# ✔ Đã convert: 473.txt
# ✔ Đã convert: 474.txt
# ✔ Đã convert: 475.txt
# ✔ Đã convert: 476.txt
# ✔ Đã convert: 477.txt
# ✔ Đã convert: 478.txt
# ✔ Đã convert: 479.txt
# ✔ Đã convert: 480.txt
# ✔ Đã convert: 481.txt
# ✔ Đã convert: 482.txt
# ✔ Đã convert: 483.txt
# ✔ Đã convert: 484.txt
# ✔ Đã convert: 485.txt
# ✔ Đã convert: 486.txt
# ✔ Đã convert: 487.txt
# ✔ Đã convert: 488.txt
# ✔ Đã convert: 489.txt
# ✔ Đã convert: 490.txt
# ✔ Đã convert: 491.txt
# ✔ Đã convert: 492.txt
# ✔ Đã convert: 493.txt
# ✔ Đã convert: 494.txt
# ✔ Đã convert: 495.txt
# ✔ Đã convert: 496.txt
# ✔ Đã convert: 497.txt
# ✔ Đã convert: 498.txt
# ✔ Đã convert: 499.txt
# ✔ Đã convert: 500.txt
# ✔ Đã convert: 501.txt
# ✔ Đã convert: 502.txt
# ✔ Đã convert: 503.txt
# ✔ Đã convert: 504.txt
# ✔ Đã convert: 505.txt
# ✔ Đã convert: 506.txt
# ✔ Đã convert: 507.txt
# ✔ Đã convert: 508.txt
# ✔ Đã convert: 509.txt
# ✔ Đã convert: 510.txt
# ✔ Đã convert: 511.txt
# ✔ Đã convert: 512.txt
# ✔ Đã convert: 513.txt
# ✔ Đã convert: 514.txt
# ✔ Đã convert: 515.txt
# ✔ Đã convert: 516.txt
# ✔ Đã convert: 517.txt
# ✔ Đã convert: 518.txt
# ✔ Đã convert: 519.txt
# ✔ Đã convert: 520.txt
# ✔ Đã convert: 521.txt
# ✔ Đã convert: 522.txt
# ✔ Đã convert: 523.txt
# ✔ Đã convert: 524.txt
# ✔ Đã convert: 525.txt
# ✔ Đã convert: 526.txt
# ✔ Đã convert: 527.txt
# ✔ Đã convert: 528.txt
# ✔ Đã convert: 529.txt
# ✔ Đã convert: 530.txt
# ✔ Đã convert: 531.txt
# ✔ Đã convert: 532.txt
# ✔ Đã convert: 533.txt
# ✔ Đã convert: 534.txt
# ✔ Đã convert: 535.txt
# ✔ Đã convert: 536.txt
# ✔ Đã convert: 537.txt
# ✔ Đã convert: 538.txt
# ✔ Đã convert: 539.txt
# ✔ Đã convert: 540.txt
# ✔ Đã convert: 541.txt
# ✔ Đã convert: 542.txt
# ✔ Đã convert: 543.txt
# ✔ Đã convert: 544.txt
# ✔ Đã convert: 545.txt
# ✔ Đã convert: 546.txt
# ✔ Đã convert: 547.txt
# ✔ Đã convert: 548.txt
# ✔ Đã convert: 549.txt
# ✔ Đã convert: 550.txt
# ✔ Đã convert: 551.txt
# ✔ Đã convert: 552.txt
# ✔ Đã convert: 553.txt
# ✔ Đã convert: 554.txt
# ✔ Đã convert: 555.txt
# ✔ Đã convert: 556.txt
# ✔ Đã convert: 557.txt
# ✔ Đã convert: 558.txt
# ✔ Đã convert: 559.txt
# ✔ Đã convert: 560.txt
# ✔ Đã convert: 561.txt
# ✔ Đã convert: 562.txt
# ✔ Đã convert: 563.txt
# ✔ Đã convert: 564.txt
# ✔ Đã convert: 565.txt
# ✔ Đã convert: 566.txt
# ✔ Đã convert: 567.txt
# ✔ Đã convert: 568.txt
# ✔ Đã convert: 569.txt
# ✔ Đã convert: 570.txt
# ✔ Đã convert: 571.txt
# ✔ Đã convert: 572.txt
# ✔ Đã convert: 573.txt
# ✔ Đã convert: 574.txt
# ✔ Đã convert: 575.txt
# ✔ Đã convert: 576.txt
# ✔ Đã convert: 577.txt
# ✔ Đã convert: 578.txt
# ✔ Đã convert: 579.txt
# ✔ Đã convert: 580.txt
# ✔ Đã convert: 581.txt
# ✔ Đã convert: 582.txt
# ✔ Đã convert: 583.txt
# ✔ Đã convert: 584.txt
# ✔ Đã convert: 585.txt
# ✔ Đã convert: 586.txt
# ✔ Đã convert: 587.txt
# ✔ Đã convert: 588.txt
# ✔ Đã convert: 589.txt
# ✔ Đã convert: 590.txt
# ✔ Đã convert: 591.txt
# ✔ Đã convert: 592.txt
# ✔ Đã convert: 593.txt
# ✔ Đã convert: 594.txt
# ✔ Đã convert: 595.txt
# ✔ Đã convert: 596.txt
# ✔ Đã convert: 597.txt
# ✔ Đã convert: 598.txt
# ✔ Đã convert: 599.txt
# ✔ Đã convert: 600.txt
# ✔ Đã convert: 601.txt
# ✔ Đã convert: 602.txt
# ✔ Đã convert: 603.txt
# ✔ Đã convert: 604.txt
# ✔ Đã convert: 605.txt
# ✔ Đã convert: 606.txt
# ✔ Đã convert: 607.txt
# ✔ Đã convert: 608.txt
# ✔ Đã convert: 609.txt
# ✔ Đã convert: 610.txt
# ✔ Đã convert: 611.txt
# ✔ Đã convert: 612.txt
# ✔ Đã convert: 613.txt
# ✔ Đã convert: 614.txt
# ✔ Đã convert: 615.txt
# ✔ Đã convert: 616.txt
# ✔ Đã convert: 617.txt
# ✔ Đã convert: 618.txt
# ✔ Đã convert: 619.txt
# ✔ Đã convert: 620.txt
# ✔ Đã convert: 621.txt
# ✔ Đã convert: 622.txt
# ✔ Đã convert: 623.txt
# ✔ Đã convert: 624.txt
# ✔ Đã convert: 625.txt
# ✔ Đã convert: 626.txt
# ✔ Đã convert: 627.txt
# ✔ Đã convert: 628.txt
# ✔ Đã convert: 629.txt
# ✔ Đã convert: 630.txt
# ✔ Đã convert: 631.txt
# ✔ Đã convert: 632.txt
# ✔ Đã convert: 633.txt
# ✔ Đã convert: 634.txt
# ✔ Đã convert: 635.txt
# ✔ Đã convert: 636.txt
# ✔ Đã convert: 637.txt
# ✔ Đã convert: 638.txt
# ✔ Đã convert: 639.txt
# ✔ Đã convert: 640.txt
# ✔ Đã convert: 641.txt
# ✔ Đã convert: 642.txt
# ✔ Đã convert: 643.txt
# ✔ Đã convert: 644.txt
# ✔ Đã convert: 645.txt
# ✔ Đã convert: 646.txt
# ✔ Đã convert: 647.txt
# ✔ Đã convert: 648.txt
# ✔ Đã convert: 649.txt
# ✔ Đã convert: 650.txt
# Hoàn tất convert toàn bộ nhãn sang YOLO format!

# %% [markdown]
# # Process Negative Set

# %%
neg_img_dir = Path("/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/negative image set")
out_label_dir = Path("/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/labels_negative")
out_label_dir.mkdir(parents=True, exist_ok=True)

ext_candidates = [".jpg", ".png", ".jpeg", ".JPG", ".PNG", ".JPEG"]

for ext in ext_candidates:
    for img_path in neg_img_dir.glob(f"*{ext}"):
        stem = img_path.stem
        out_file = out_label_dir / f"{stem}.txt"
        out_file.write_text("", encoding="utf-8")  
        print(f"Tạo nhãn rỗng cho: {out_file.name}")

print("Hoàn tất tạo nhãn rỗng cho negative images")
# Out:
# Tạo nhãn rỗng cho: 073.txt
# Tạo nhãn rỗng cho: 060.txt
# Tạo nhãn rỗng cho: 124.txt
# Tạo nhãn rỗng cho: 066.txt
# Tạo nhãn rỗng cho: 075.txt
# Tạo nhãn rỗng cho: 051.txt
# Tạo nhãn rỗng cho: 048.txt
# Tạo nhãn rỗng cho: 043.txt
# Tạo nhãn rỗng cho: 128.txt
# Tạo nhãn rỗng cho: 086.txt
# Tạo nhãn rỗng cho: 007.txt
# Tạo nhãn rỗng cho: 134.txt
# Tạo nhãn rỗng cho: 144.txt
# Tạo nhãn rỗng cho: 113.txt
# Tạo nhãn rỗng cho: 055.txt
# Tạo nhãn rỗng cho: 071.txt
# Tạo nhãn rỗng cho: 026.txt
# Tạo nhãn rỗng cho: 141.txt
# Tạo nhãn rỗng cho: 004.txt
# Tạo nhãn rỗng cho: 044.txt
# Tạo nhãn rỗng cho: 023.txt
# Tạo nhãn rỗng cho: 097.txt
# Tạo nhãn rỗng cho: 003.txt
# Tạo nhãn rỗng cho: 015.txt
# Tạo nhãn rỗng cho: 034.txt
# Tạo nhãn rỗng cho: 076.txt
# Tạo nhãn rỗng cho: 104.txt
# Tạo nhãn rỗng cho: 147.txt
# Tạo nhãn rỗng cho: 126.txt
# Tạo nhãn rỗng cho: 119.txt
# Tạo nhãn rỗng cho: 028.txt
# Tạo nhãn rỗng cho: 149.txt
# Tạo nhãn rỗng cho: 032.txt
# Tạo nhãn rỗng cho: 011.txt
# Tạo nhãn rỗng cho: 116.txt
# Tạo nhãn rỗng cho: 098.txt
# Tạo nhãn rỗng cho: 040.txt
# Tạo nhãn rỗng cho: 070.txt
# Tạo nhãn rỗng cho: 016.txt
# Tạo nhãn rỗng cho: 058.txt
# Tạo nhãn rỗng cho: 057.txt
# Tạo nhãn rỗng cho: 054.txt
# Tạo nhãn rỗng cho: 012.txt
# Tạo nhãn rỗng cho: 013.txt
# Tạo nhãn rỗng cho: 109.txt
# Tạo nhãn rỗng cho: 037.txt
# Tạo nhãn rỗng cho: 074.txt
# Tạo nhãn rỗng cho: 067.txt
# Tạo nhãn rỗng cho: 021.txt
# Tạo nhãn rỗng cho: 030.txt
# Tạo nhãn rỗng cho: 135.txt
# Tạo nhãn rỗng cho: 059.txt
# Tạo nhãn rỗng cho: 022.txt
# Tạo nhãn rỗng cho: 017.txt
# Tạo nhãn rỗng cho: 138.txt
# Tạo nhãn rỗng cho: 115.txt
# Tạo nhãn rỗng cho: 025.txt
# Tạo nhãn rỗng cho: 065.txt
# Tạo nhãn rỗng cho: 079.txt
# Tạo nhãn rỗng cho: 121.txt
# Tạo nhãn rỗng cho: 072.txt
# Tạo nhãn rỗng cho: 083.txt
# Tạo nhãn rỗng cho: 150.txt
# Tạo nhãn rỗng cho: 047.txt
# Tạo nhãn rỗng cho: 089.txt
# Tạo nhãn rỗng cho: 095.txt
# Tạo nhãn rỗng cho: 080.txt
# Tạo nhãn rỗng cho: 082.txt
# Tạo nhãn rỗng cho: 125.txt
# Tạo nhãn rỗng cho: 117.txt
# Tạo nhãn rỗng cho: 139.txt
# Tạo nhãn rỗng cho: 042.txt
# Tạo nhãn rỗng cho: 063.txt
# Tạo nhãn rỗng cho: 062.txt
# Tạo nhãn rỗng cho: 009.txt
# Tạo nhãn rỗng cho: 029.txt
# Tạo nhãn rỗng cho: 136.txt
# Tạo nhãn rỗng cho: 002.txt
# Tạo nhãn rỗng cho: 081.txt
# Tạo nhãn rỗng cho: 142.txt
# Tạo nhãn rỗng cho: 145.txt
# Tạo nhãn rỗng cho: 046.txt
# Tạo nhãn rỗng cho: 001.txt
# Tạo nhãn rỗng cho: 112.txt
# Tạo nhãn rỗng cho: 050.txt
# Tạo nhãn rỗng cho: 024.txt
# Tạo nhãn rỗng cho: 031.txt
# Tạo nhãn rỗng cho: 146.txt
# Tạo nhãn rỗng cho: 102.txt
# Tạo nhãn rỗng cho: 107.txt
# Tạo nhãn rỗng cho: 041.txt
# Tạo nhãn rỗng cho: 053.txt
# Tạo nhãn rỗng cho: 090.txt
# Tạo nhãn rỗng cho: 129.txt
# Tạo nhãn rỗng cho: 110.txt
# Tạo nhãn rỗng cho: 131.txt
# Tạo nhãn rỗng cho: 143.txt
# Tạo nhãn rỗng cho: 091.txt
# Tạo nhãn rỗng cho: 049.txt
# Tạo nhãn rỗng cho: 148.txt
# Tạo nhãn rỗng cho: 103.txt
# Tạo nhãn rỗng cho: 122.txt
# Tạo nhãn rỗng cho: 105.txt
# Tạo nhãn rỗng cho: 018.txt
# Tạo nhãn rỗng cho: 061.txt
# Tạo nhãn rỗng cho: 078.txt
# Tạo nhãn rỗng cho: 140.txt
# Tạo nhãn rỗng cho: 027.txt
# Tạo nhãn rỗng cho: 120.txt
# Tạo nhãn rỗng cho: 106.txt
# Tạo nhãn rỗng cho: 014.txt
# Tạo nhãn rỗng cho: 045.txt
# Tạo nhãn rỗng cho: 094.txt
# Tạo nhãn rỗng cho: 137.txt
# Tạo nhãn rỗng cho: 130.txt
# Tạo nhãn rỗng cho: 056.txt
# Tạo nhãn rỗng cho: 036.txt
# Tạo nhãn rỗng cho: 108.txt
# Tạo nhãn rỗng cho: 088.txt
# Tạo nhãn rỗng cho: 052.txt
# Tạo nhãn rỗng cho: 006.txt
# Tạo nhãn rỗng cho: 132.txt
# Tạo nhãn rỗng cho: 118.txt
# Tạo nhãn rỗng cho: 033.txt
# Tạo nhãn rỗng cho: 133.txt
# Tạo nhãn rỗng cho: 010.txt
# Tạo nhãn rỗng cho: 087.txt
# Tạo nhãn rỗng cho: 069.txt
# Tạo nhãn rỗng cho: 100.txt
# Tạo nhãn rỗng cho: 020.txt
# Tạo nhãn rỗng cho: 096.txt
# Tạo nhãn rỗng cho: 111.txt
# Tạo nhãn rỗng cho: 035.txt
# Tạo nhãn rỗng cho: 101.txt
# Tạo nhãn rỗng cho: 008.txt
# Tạo nhãn rỗng cho: 005.txt
# Tạo nhãn rỗng cho: 127.txt
# Tạo nhãn rỗng cho: 093.txt
# Tạo nhãn rỗng cho: 064.txt
# Tạo nhãn rỗng cho: 068.txt
# Tạo nhãn rỗng cho: 019.txt
# Tạo nhãn rỗng cho: 114.txt
# Tạo nhãn rỗng cho: 123.txt
# Tạo nhãn rỗng cho: 084.txt
# Tạo nhãn rỗng cho: 077.txt
# Tạo nhãn rỗng cho: 099.txt
# Tạo nhãn rỗng cho: 038.txt
# Tạo nhãn rỗng cho: 092.txt
# Tạo nhãn rỗng cho: 085.txt
# Tạo nhãn rỗng cho: 039.txt
# Hoàn tất tạo nhãn rỗng cho negative images

# %%
start_idx = 651

for i, img_path in enumerate(sorted(neg_img_dir.glob("*.jpg")), start=start_idx):
    new_name = f"{i}.jpg"
    new_img_path = img_path.parent / new_name

   
    img_path.rename(new_img_path)

    
    old_label = out_label_dir / f"{img_path.stem}.txt"
    new_label = out_label_dir / f"{i}.txt"
    if old_label.exists():
        old_label.rename(new_label)
    else:
        new_label.write_text("", encoding="utf-8")

    print(f"✔ {img_path.name} -> {new_name}, nhãn {new_label.name}")

print("Hoàn tất đổi tên ảnh negative và nhãn rỗng từ 651-800")
# Out:
# ✔ 001.jpg -> 651.jpg, nhãn 651.txt
# ✔ 002.jpg -> 652.jpg, nhãn 652.txt
# ✔ 003.jpg -> 653.jpg, nhãn 653.txt
# ✔ 004.jpg -> 654.jpg, nhãn 654.txt
# ✔ 005.jpg -> 655.jpg, nhãn 655.txt
# ✔ 006.jpg -> 656.jpg, nhãn 656.txt
# ✔ 007.jpg -> 657.jpg, nhãn 657.txt
# ✔ 008.jpg -> 658.jpg, nhãn 658.txt
# ✔ 009.jpg -> 659.jpg, nhãn 659.txt
# ✔ 010.jpg -> 660.jpg, nhãn 660.txt
# ✔ 011.jpg -> 661.jpg, nhãn 661.txt
# ✔ 012.jpg -> 662.jpg, nhãn 662.txt
# ✔ 013.jpg -> 663.jpg, nhãn 663.txt
# ✔ 014.jpg -> 664.jpg, nhãn 664.txt
# ✔ 015.jpg -> 665.jpg, nhãn 665.txt
# ✔ 016.jpg -> 666.jpg, nhãn 666.txt
# ✔ 017.jpg -> 667.jpg, nhãn 667.txt
# ✔ 018.jpg -> 668.jpg, nhãn 668.txt
# ✔ 019.jpg -> 669.jpg, nhãn 669.txt
# ✔ 020.jpg -> 670.jpg, nhãn 670.txt
# ✔ 021.jpg -> 671.jpg, nhãn 671.txt
# ✔ 022.jpg -> 672.jpg, nhãn 672.txt
# ✔ 023.jpg -> 673.jpg, nhãn 673.txt
# ✔ 024.jpg -> 674.jpg, nhãn 674.txt
# ✔ 025.jpg -> 675.jpg, nhãn 675.txt
# ✔ 026.jpg -> 676.jpg, nhãn 676.txt
# ✔ 027.jpg -> 677.jpg, nhãn 677.txt
# ✔ 028.jpg -> 678.jpg, nhãn 678.txt
# ✔ 029.jpg -> 679.jpg, nhãn 679.txt
# ✔ 030.jpg -> 680.jpg, nhãn 680.txt
# ✔ 031.jpg -> 681.jpg, nhãn 681.txt
# ✔ 032.jpg -> 682.jpg, nhãn 682.txt
# ✔ 033.jpg -> 683.jpg, nhãn 683.txt
# ✔ 034.jpg -> 684.jpg, nhãn 684.txt
# ✔ 035.jpg -> 685.jpg, nhãn 685.txt
# ✔ 036.jpg -> 686.jpg, nhãn 686.txt
# ✔ 037.jpg -> 687.jpg, nhãn 687.txt
# ✔ 038.jpg -> 688.jpg, nhãn 688.txt
# ✔ 039.jpg -> 689.jpg, nhãn 689.txt
# ✔ 040.jpg -> 690.jpg, nhãn 690.txt
# ✔ 041.jpg -> 691.jpg, nhãn 691.txt
# ✔ 042.jpg -> 692.jpg, nhãn 692.txt
# ✔ 043.jpg -> 693.jpg, nhãn 693.txt
# ✔ 044.jpg -> 694.jpg, nhãn 694.txt
# ✔ 045.jpg -> 695.jpg, nhãn 695.txt
# ✔ 046.jpg -> 696.jpg, nhãn 696.txt
# ✔ 047.jpg -> 697.jpg, nhãn 697.txt
# ✔ 048.jpg -> 698.jpg, nhãn 698.txt
# ✔ 049.jpg -> 699.jpg, nhãn 699.txt
# ✔ 050.jpg -> 700.jpg, nhãn 700.txt
# ✔ 051.jpg -> 701.jpg, nhãn 701.txt
# ✔ 052.jpg -> 702.jpg, nhãn 702.txt
# ✔ 053.jpg -> 703.jpg, nhãn 703.txt
# ✔ 054.jpg -> 704.jpg, nhãn 704.txt
# ✔ 055.jpg -> 705.jpg, nhãn 705.txt
# ✔ 056.jpg -> 706.jpg, nhãn 706.txt
# ✔ 057.jpg -> 707.jpg, nhãn 707.txt
# ✔ 058.jpg -> 708.jpg, nhãn 708.txt
# ✔ 059.jpg -> 709.jpg, nhãn 709.txt
# ✔ 060.jpg -> 710.jpg, nhãn 710.txt
# ✔ 061.jpg -> 711.jpg, nhãn 711.txt
# ✔ 062.jpg -> 712.jpg, nhãn 712.txt
# ✔ 063.jpg -> 713.jpg, nhãn 713.txt
# ✔ 064.jpg -> 714.jpg, nhãn 714.txt
# ✔ 065.jpg -> 715.jpg, nhãn 715.txt
# ✔ 066.jpg -> 716.jpg, nhãn 716.txt
# ✔ 067.jpg -> 717.jpg, nhãn 717.txt
# ✔ 068.jpg -> 718.jpg, nhãn 718.txt
# ✔ 069.jpg -> 719.jpg, nhãn 719.txt
# ✔ 070.jpg -> 720.jpg, nhãn 720.txt
# ✔ 071.jpg -> 721.jpg, nhãn 721.txt
# ✔ 072.jpg -> 722.jpg, nhãn 722.txt
# ✔ 073.jpg -> 723.jpg, nhãn 723.txt
# ✔ 074.jpg -> 724.jpg, nhãn 724.txt
# ✔ 075.jpg -> 725.jpg, nhãn 725.txt
# ✔ 076.jpg -> 726.jpg, nhãn 726.txt
# ✔ 077.jpg -> 727.jpg, nhãn 727.txt
# ✔ 078.jpg -> 728.jpg, nhãn 728.txt
# ✔ 079.jpg -> 729.jpg, nhãn 729.txt
# ✔ 080.jpg -> 730.jpg, nhãn 730.txt
# ✔ 081.jpg -> 731.jpg, nhãn 731.txt
# ✔ 082.jpg -> 732.jpg, nhãn 732.txt
# ✔ 083.jpg -> 733.jpg, nhãn 733.txt
# ✔ 084.jpg -> 734.jpg, nhãn 734.txt
# ✔ 085.jpg -> 735.jpg, nhãn 735.txt
# ✔ 086.jpg -> 736.jpg, nhãn 736.txt
# ✔ 087.jpg -> 737.jpg, nhãn 737.txt
# ✔ 088.jpg -> 738.jpg, nhãn 738.txt
# ✔ 089.jpg -> 739.jpg, nhãn 739.txt
# ✔ 090.jpg -> 740.jpg, nhãn 740.txt
# ✔ 091.jpg -> 741.jpg, nhãn 741.txt
# ✔ 092.jpg -> 742.jpg, nhãn 742.txt
# ✔ 093.jpg -> 743.jpg, nhãn 743.txt
# ✔ 094.jpg -> 744.jpg, nhãn 744.txt
# ✔ 095.jpg -> 745.jpg, nhãn 745.txt
# ✔ 096.jpg -> 746.jpg, nhãn 746.txt
# ✔ 097.jpg -> 747.jpg, nhãn 747.txt
# ✔ 098.jpg -> 748.jpg, nhãn 748.txt
# ✔ 099.jpg -> 749.jpg, nhãn 749.txt
# ✔ 100.jpg -> 750.jpg, nhãn 750.txt
# ✔ 101.jpg -> 751.jpg, nhãn 751.txt
# ✔ 102.jpg -> 752.jpg, nhãn 752.txt
# ✔ 103.jpg -> 753.jpg, nhãn 753.txt
# ✔ 104.jpg -> 754.jpg, nhãn 754.txt
# ✔ 105.jpg -> 755.jpg, nhãn 755.txt
# ✔ 106.jpg -> 756.jpg, nhãn 756.txt
# ✔ 107.jpg -> 757.jpg, nhãn 757.txt
# ✔ 108.jpg -> 758.jpg, nhãn 758.txt
# ✔ 109.jpg -> 759.jpg, nhãn 759.txt
# ✔ 110.jpg -> 760.jpg, nhãn 760.txt
# ✔ 111.jpg -> 761.jpg, nhãn 761.txt
# ✔ 112.jpg -> 762.jpg, nhãn 762.txt
# ✔ 113.jpg -> 763.jpg, nhãn 763.txt
# ✔ 114.jpg -> 764.jpg, nhãn 764.txt
# ✔ 115.jpg -> 765.jpg, nhãn 765.txt
# ✔ 116.jpg -> 766.jpg, nhãn 766.txt
# ✔ 117.jpg -> 767.jpg, nhãn 767.txt
# ✔ 118.jpg -> 768.jpg, nhãn 768.txt
# ✔ 119.jpg -> 769.jpg, nhãn 769.txt
# ✔ 120.jpg -> 770.jpg, nhãn 770.txt
# ✔ 121.jpg -> 771.jpg, nhãn 771.txt
# ✔ 122.jpg -> 772.jpg, nhãn 772.txt
# ✔ 123.jpg -> 773.jpg, nhãn 773.txt
# ✔ 124.jpg -> 774.jpg, nhãn 774.txt
# ✔ 125.jpg -> 775.jpg, nhãn 775.txt
# ✔ 126.jpg -> 776.jpg, nhãn 776.txt
# ✔ 127.jpg -> 777.jpg, nhãn 777.txt
# ✔ 128.jpg -> 778.jpg, nhãn 778.txt
# ✔ 129.jpg -> 779.jpg, nhãn 779.txt
# ✔ 130.jpg -> 780.jpg, nhãn 780.txt
# ✔ 131.jpg -> 781.jpg, nhãn 781.txt
# ✔ 132.jpg -> 782.jpg, nhãn 782.txt
# ✔ 133.jpg -> 783.jpg, nhãn 783.txt
# ✔ 134.jpg -> 784.jpg, nhãn 784.txt
# ✔ 135.jpg -> 785.jpg, nhãn 785.txt
# ✔ 136.jpg -> 786.jpg, nhãn 786.txt
# ✔ 137.jpg -> 787.jpg, nhãn 787.txt
# ✔ 138.jpg -> 788.jpg, nhãn 788.txt
# ✔ 139.jpg -> 789.jpg, nhãn 789.txt
# ✔ 140.jpg -> 790.jpg, nhãn 790.txt
# ✔ 141.jpg -> 791.jpg, nhãn 791.txt
# ✔ 142.jpg -> 792.jpg, nhãn 792.txt
# ✔ 143.jpg -> 793.jpg, nhãn 793.txt
# ✔ 144.jpg -> 794.jpg, nhãn 794.txt
# ✔ 145.jpg -> 795.jpg, nhãn 795.txt
# ✔ 146.jpg -> 796.jpg, nhãn 796.txt
# ✔ 147.jpg -> 797.jpg, nhãn 797.txt
# ✔ 148.jpg -> 798.jpg, nhãn 798.txt
# ✔ 149.jpg -> 799.jpg, nhãn 799.txt
# ✔ 150.jpg -> 800.jpg, nhãn 800.txt
# Hoàn tất đổi tên ảnh negative và nhãn rỗng từ 651-800

# %%
# Copy ảnh negative -> positive image set
for img_path in sorted(neg_img_dir.glob("*.jpg")):
    shutil.copy(img_path, img_dir / img_path.name)
    print(f"Copy ảnh {img_path.name} -> {img_dir.name}")

# Copy nhãn negative (rỗng) -> ground truth
for lbl_path in sorted(out_label_dir.glob("*.txt")):
    shutil.copy(lbl_path, gt_dir / lbl_path.name)
    print(f"Copy nhãn {lbl_path.name} -> {gt_dir.name}")

print("Hoàn tất gộp negative vào positive")
# Out:
# Copy ảnh 651.jpg -> positive image set
# Copy ảnh 652.jpg -> positive image set
# Copy ảnh 653.jpg -> positive image set
# Copy ảnh 654.jpg -> positive image set
# Copy ảnh 655.jpg -> positive image set
# Copy ảnh 656.jpg -> positive image set
# Copy ảnh 657.jpg -> positive image set
# Copy ảnh 658.jpg -> positive image set
# Copy ảnh 659.jpg -> positive image set
# Copy ảnh 660.jpg -> positive image set
# Copy ảnh 661.jpg -> positive image set
# Copy ảnh 662.jpg -> positive image set
# Copy ảnh 663.jpg -> positive image set
# Copy ảnh 664.jpg -> positive image set
# Copy ảnh 665.jpg -> positive image set
# Copy ảnh 666.jpg -> positive image set
# Copy ảnh 667.jpg -> positive image set
# Copy ảnh 668.jpg -> positive image set
# Copy ảnh 669.jpg -> positive image set
# Copy ảnh 670.jpg -> positive image set
# Copy ảnh 671.jpg -> positive image set
# Copy ảnh 672.jpg -> positive image set
# Copy ảnh 673.jpg -> positive image set
# Copy ảnh 674.jpg -> positive image set
# Copy ảnh 675.jpg -> positive image set
# Copy ảnh 676.jpg -> positive image set
# Copy ảnh 677.jpg -> positive image set
# Copy ảnh 678.jpg -> positive image set
# Copy ảnh 679.jpg -> positive image set
# Copy ảnh 680.jpg -> positive image set
# Copy ảnh 681.jpg -> positive image set
# Copy ảnh 682.jpg -> positive image set
# Copy ảnh 683.jpg -> positive image set
# Copy ảnh 684.jpg -> positive image set
# Copy ảnh 685.jpg -> positive image set
# Copy ảnh 686.jpg -> positive image set
# Copy ảnh 687.jpg -> positive image set
# Copy ảnh 688.jpg -> positive image set
# Copy ảnh 689.jpg -> positive image set
# Copy ảnh 690.jpg -> positive image set
# Copy ảnh 691.jpg -> positive image set
# Copy ảnh 692.jpg -> positive image set
# Copy ảnh 693.jpg -> positive image set
# Copy ảnh 694.jpg -> positive image set
# Copy ảnh 695.jpg -> positive image set
# Copy ảnh 696.jpg -> positive image set
# Copy ảnh 697.jpg -> positive image set
# Copy ảnh 698.jpg -> positive image set
# Copy ảnh 699.jpg -> positive image set
# Copy ảnh 700.jpg -> positive image set
# Copy ảnh 701.jpg -> positive image set
# Copy ảnh 702.jpg -> positive image set
# Copy ảnh 703.jpg -> positive image set
# Copy ảnh 704.jpg -> positive image set
# Copy ảnh 705.jpg -> positive image set
# Copy ảnh 706.jpg -> positive image set
# Copy ảnh 707.jpg -> positive image set
# Copy ảnh 708.jpg -> positive image set
# Copy ảnh 709.jpg -> positive image set
# Copy ảnh 710.jpg -> positive image set
# Copy ảnh 711.jpg -> positive image set
# Copy ảnh 712.jpg -> positive image set
# Copy ảnh 713.jpg -> positive image set
# Copy ảnh 714.jpg -> positive image set
# Copy ảnh 715.jpg -> positive image set
# Copy ảnh 716.jpg -> positive image set
# Copy ảnh 717.jpg -> positive image set
# Copy ảnh 718.jpg -> positive image set
# Copy ảnh 719.jpg -> positive image set
# Copy ảnh 720.jpg -> positive image set
# Copy ảnh 721.jpg -> positive image set
# Copy ảnh 722.jpg -> positive image set
# Copy ảnh 723.jpg -> positive image set
# Copy ảnh 724.jpg -> positive image set
# Copy ảnh 725.jpg -> positive image set
# Copy ảnh 726.jpg -> positive image set
# Copy ảnh 727.jpg -> positive image set
# Copy ảnh 728.jpg -> positive image set
# Copy ảnh 729.jpg -> positive image set
# Copy ảnh 730.jpg -> positive image set
# Copy ảnh 731.jpg -> positive image set
# Copy ảnh 732.jpg -> positive image set
# Copy ảnh 733.jpg -> positive image set
# Copy ảnh 734.jpg -> positive image set
# Copy ảnh 735.jpg -> positive image set
# Copy ảnh 736.jpg -> positive image set
# Copy ảnh 737.jpg -> positive image set
# Copy ảnh 738.jpg -> positive image set
# Copy ảnh 739.jpg -> positive image set
# Copy ảnh 740.jpg -> positive image set
# Copy ảnh 741.jpg -> positive image set
# Copy ảnh 742.jpg -> positive image set
# Copy ảnh 743.jpg -> positive image set
# Copy ảnh 744.jpg -> positive image set
# Copy ảnh 745.jpg -> positive image set
# Copy ảnh 746.jpg -> positive image set
# Copy ảnh 747.jpg -> positive image set
# Copy ảnh 748.jpg -> positive image set
# Copy ảnh 749.jpg -> positive image set
# Copy ảnh 750.jpg -> positive image set
# Copy ảnh 751.jpg -> positive image set
# Copy ảnh 752.jpg -> positive image set
# Copy ảnh 753.jpg -> positive image set
# Copy ảnh 754.jpg -> positive image set
# Copy ảnh 755.jpg -> positive image set
# Copy ảnh 756.jpg -> positive image set
# Copy ảnh 757.jpg -> positive image set
# Copy ảnh 758.jpg -> positive image set
# Copy ảnh 759.jpg -> positive image set
# Copy ảnh 760.jpg -> positive image set
# Copy ảnh 761.jpg -> positive image set
# Copy ảnh 762.jpg -> positive image set
# Copy ảnh 763.jpg -> positive image set
# Copy ảnh 764.jpg -> positive image set
# Copy ảnh 765.jpg -> positive image set
# Copy ảnh 766.jpg -> positive image set
# Copy ảnh 767.jpg -> positive image set
# Copy ảnh 768.jpg -> positive image set
# Copy ảnh 769.jpg -> positive image set
# Copy ảnh 770.jpg -> positive image set
# Copy ảnh 771.jpg -> positive image set
# Copy ảnh 772.jpg -> positive image set
# Copy ảnh 773.jpg -> positive image set
# Copy ảnh 774.jpg -> positive image set
# Copy ảnh 775.jpg -> positive image set
# Copy ảnh 776.jpg -> positive image set
# Copy ảnh 777.jpg -> positive image set
# Copy ảnh 778.jpg -> positive image set
# Copy ảnh 779.jpg -> positive image set
# Copy ảnh 780.jpg -> positive image set
# Copy ảnh 781.jpg -> positive image set
# Copy ảnh 782.jpg -> positive image set
# Copy ảnh 783.jpg -> positive image set
# Copy ảnh 784.jpg -> positive image set
# Copy ảnh 785.jpg -> positive image set
# Copy ảnh 786.jpg -> positive image set
# Copy ảnh 787.jpg -> positive image set
# Copy ảnh 788.jpg -> positive image set
# Copy ảnh 789.jpg -> positive image set
# Copy ảnh 790.jpg -> positive image set
# Copy ảnh 791.jpg -> positive image set
# Copy ảnh 792.jpg -> positive image set
# Copy ảnh 793.jpg -> positive image set
# Copy ảnh 794.jpg -> positive image set
# Copy ảnh 795.jpg -> positive image set
# Copy ảnh 796.jpg -> positive image set
# Copy ảnh 797.jpg -> positive image set
# Copy ảnh 798.jpg -> positive image set
# Copy ảnh 799.jpg -> positive image set
# Copy ảnh 800.jpg -> positive image set
# Copy nhãn 651.txt -> ground truth
# Copy nhãn 652.txt -> ground truth
# Copy nhãn 653.txt -> ground truth
# Copy nhãn 654.txt -> ground truth
# Copy nhãn 655.txt -> ground truth
# Copy nhãn 656.txt -> ground truth
# Copy nhãn 657.txt -> ground truth
# Copy nhãn 658.txt -> ground truth
# Copy nhãn 659.txt -> ground truth
# Copy nhãn 660.txt -> ground truth
# Copy nhãn 661.txt -> ground truth
# Copy nhãn 662.txt -> ground truth
# Copy nhãn 663.txt -> ground truth
# Copy nhãn 664.txt -> ground truth
# Copy nhãn 665.txt -> ground truth
# Copy nhãn 666.txt -> ground truth
# Copy nhãn 667.txt -> ground truth
# Copy nhãn 668.txt -> ground truth
# Copy nhãn 669.txt -> ground truth
# Copy nhãn 670.txt -> ground truth
# Copy nhãn 671.txt -> ground truth
# Copy nhãn 672.txt -> ground truth
# Copy nhãn 673.txt -> ground truth
# Copy nhãn 674.txt -> ground truth
# Copy nhãn 675.txt -> ground truth
# Copy nhãn 676.txt -> ground truth
# Copy nhãn 677.txt -> ground truth
# Copy nhãn 678.txt -> ground truth
# Copy nhãn 679.txt -> ground truth
# Copy nhãn 680.txt -> ground truth
# Copy nhãn 681.txt -> ground truth
# Copy nhãn 682.txt -> ground truth
# Copy nhãn 683.txt -> ground truth
# Copy nhãn 684.txt -> ground truth
# Copy nhãn 685.txt -> ground truth
# Copy nhãn 686.txt -> ground truth
# Copy nhãn 687.txt -> ground truth
# Copy nhãn 688.txt -> ground truth
# Copy nhãn 689.txt -> ground truth
# Copy nhãn 690.txt -> ground truth
# Copy nhãn 691.txt -> ground truth
# Copy nhãn 692.txt -> ground truth
# Copy nhãn 693.txt -> ground truth
# Copy nhãn 694.txt -> ground truth
# Copy nhãn 695.txt -> ground truth
# Copy nhãn 696.txt -> ground truth
# Copy nhãn 697.txt -> ground truth
# Copy nhãn 698.txt -> ground truth
# Copy nhãn 699.txt -> ground truth
# Copy nhãn 700.txt -> ground truth
# Copy nhãn 701.txt -> ground truth
# Copy nhãn 702.txt -> ground truth
# Copy nhãn 703.txt -> ground truth
# Copy nhãn 704.txt -> ground truth
# Copy nhãn 705.txt -> ground truth
# Copy nhãn 706.txt -> ground truth
# Copy nhãn 707.txt -> ground truth
# Copy nhãn 708.txt -> ground truth
# Copy nhãn 709.txt -> ground truth
# Copy nhãn 710.txt -> ground truth
# Copy nhãn 711.txt -> ground truth
# Copy nhãn 712.txt -> ground truth
# Copy nhãn 713.txt -> ground truth
# Copy nhãn 714.txt -> ground truth
# Copy nhãn 715.txt -> ground truth
# Copy nhãn 716.txt -> ground truth
# Copy nhãn 717.txt -> ground truth
# Copy nhãn 718.txt -> ground truth
# Copy nhãn 719.txt -> ground truth
# Copy nhãn 720.txt -> ground truth
# Copy nhãn 721.txt -> ground truth
# Copy nhãn 722.txt -> ground truth
# Copy nhãn 723.txt -> ground truth
# Copy nhãn 724.txt -> ground truth
# Copy nhãn 725.txt -> ground truth
# Copy nhãn 726.txt -> ground truth
# Copy nhãn 727.txt -> ground truth
# Copy nhãn 728.txt -> ground truth
# Copy nhãn 729.txt -> ground truth
# Copy nhãn 730.txt -> ground truth
# Copy nhãn 731.txt -> ground truth
# Copy nhãn 732.txt -> ground truth
# Copy nhãn 733.txt -> ground truth
# Copy nhãn 734.txt -> ground truth
# Copy nhãn 735.txt -> ground truth
# Copy nhãn 736.txt -> ground truth
# Copy nhãn 737.txt -> ground truth
# Copy nhãn 738.txt -> ground truth
# Copy nhãn 739.txt -> ground truth
# Copy nhãn 740.txt -> ground truth
# Copy nhãn 741.txt -> ground truth
# Copy nhãn 742.txt -> ground truth
# Copy nhãn 743.txt -> ground truth
# Copy nhãn 744.txt -> ground truth
# Copy nhãn 745.txt -> ground truth
# Copy nhãn 746.txt -> ground truth
# Copy nhãn 747.txt -> ground truth
# Copy nhãn 748.txt -> ground truth
# Copy nhãn 749.txt -> ground truth
# Copy nhãn 750.txt -> ground truth
# Copy nhãn 751.txt -> ground truth
# Copy nhãn 752.txt -> ground truth
# Copy nhãn 753.txt -> ground truth
# Copy nhãn 754.txt -> ground truth
# Copy nhãn 755.txt -> ground truth
# Copy nhãn 756.txt -> ground truth
# Copy nhãn 757.txt -> ground truth
# Copy nhãn 758.txt -> ground truth
# Copy nhãn 759.txt -> ground truth
# Copy nhãn 760.txt -> ground truth
# Copy nhãn 761.txt -> ground truth
# Copy nhãn 762.txt -> ground truth
# Copy nhãn 763.txt -> ground truth
# Copy nhãn 764.txt -> ground truth
# Copy nhãn 765.txt -> ground truth
# Copy nhãn 766.txt -> ground truth
# Copy nhãn 767.txt -> ground truth
# Copy nhãn 768.txt -> ground truth
# Copy nhãn 769.txt -> ground truth
# Copy nhãn 770.txt -> ground truth
# Copy nhãn 771.txt -> ground truth
# Copy nhãn 772.txt -> ground truth
# Copy nhãn 773.txt -> ground truth
# Copy nhãn 774.txt -> ground truth
# Copy nhãn 775.txt -> ground truth
# Copy nhãn 776.txt -> ground truth
# Copy nhãn 777.txt -> ground truth
# Copy nhãn 778.txt -> ground truth
# Copy nhãn 779.txt -> ground truth
# Copy nhãn 780.txt -> ground truth
# Copy nhãn 781.txt -> ground truth
# Copy nhãn 782.txt -> ground truth
# Copy nhãn 783.txt -> ground truth
# Copy nhãn 784.txt -> ground truth
# Copy nhãn 785.txt -> ground truth
# Copy nhãn 786.txt -> ground truth
# Copy nhãn 787.txt -> ground truth
# Copy nhãn 788.txt -> ground truth
# Copy nhãn 789.txt -> ground truth
# Copy nhãn 790.txt -> ground truth
# Copy nhãn 791.txt -> ground truth
# Copy nhãn 792.txt -> ground truth
# Copy nhãn 793.txt -> ground truth
# Copy nhãn 794.txt -> ground truth
# Copy nhãn 795.txt -> ground truth
# Copy nhãn 796.txt -> ground truth
# Copy nhãn 797.txt -> ground truth
# Copy nhãn 798.txt -> ground truth
# Copy nhãn 799.txt -> ground truth
# Copy nhãn 800.txt -> ground truth
# Hoàn tất gộp negative vào positive

# %% [markdown]
# # Split_Train_Test

# %%
out_dir = Path("/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/data_truth")
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

for split in ["train", "val", "test"]:
    os.makedirs(os.path.join(out_dir, "images", split), exist_ok=True)
    os.makedirs(os.path.join(out_dir, "labels", split), exist_ok=True)
    
image_files = [f for f in os.listdir(img_dir) if f.endswith(('.jpg', '.png'))]
image_files = [f for f in image_files if os.path.exists(os.path.join(gt_dir, os.path.splitext(f)[0] + ".txt"))]

random.shuffle(image_files)

n_total = len(image_files)
n_train = int(train_ratio * n_total)
n_val = int(val_ratio * n_total)
n_test = n_total - n_train - n_val


train_files = image_files[:n_train]
val_files = image_files[n_train:n_train + n_val]
test_files = image_files[n_train + n_val:]


def copy_files(files, split):
    for file in tqdm(files, desc=f"Copying {split}"):
        name = os.path.splitext(file)[0]
        img_src = os.path.join(img_dir, file)
        label_src = os.path.join(gt_dir, name + ".txt")

        img_dst = os.path.join(out_dir, "images", split, file)
        label_dst = os.path.join(out_dir, "labels", split, name + ".txt")

        shutil.copy(img_src, img_dst)
        shutil.copy(label_src, label_dst)
        
        
copy_files(train_files, "train")
copy_files(val_files, "val")
copy_files(test_files, "test")
# Out:
# Copying train: 100%|██████████| 560/560 [00:00<00:00, 4722.00it/s]
# Copying val: 100%|██████████| 120/120 [00:00<00:00, 3658.06it/s]
# Copying test: 100%|██████████| 120/120 [00:00<00:00, 6269.20it/s]
