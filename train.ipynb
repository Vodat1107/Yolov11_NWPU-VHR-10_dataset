# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

# %%
results = model.train(
    data="/media/HDD3/datvo/Yolo_with_NWPU-VHR-10_ObjectDetection/NWPU VHR-10 dataset/yolo.yaml",
    epochs=120,
    batch=32,
    device="0,1"   
)
# Out:
# Ultralytics 8.3.199 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24150MiB)
#                                                         CUDA:1 (NVIDIA GeForce RTX 3090, 24148MiB)
# ...
